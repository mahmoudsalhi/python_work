# %%
import requests
import string
from bs4 import BeautifulSoup

# %%
def get_and_parse_wikipedia_page(url):
        response = requests.get(url)

        response.raise_for_status() 

        soup = BeautifulSoup(response.content, 'html.parser')

        main_content_paragraphs = soup.select("#mw-content-text p")  
    
        for paragraph in main_content_paragraphs:
            print(paragraph.get_text())

url= "https://en.wikipedia.org/wiki/Python_(programming_language)"
get_and_parse_wikipedia_page(url)
# Out:
# Python is a high-level, general-purpose programming language. Its design philosophy emphasizes code readability with the use of significant indentation via the off-side rule.[34]
#
# Python is dynamically typed and garbage-collected. It supports multiple programming paradigms, including structured (particularly procedural), object-oriented and functional programming. It is often described as a "batteries included" language due to its comprehensive standard library.[35][36]
#
# Guido van Rossum began working on Python in the late 1980s as a successor to the ABC programming language and first released it in 1991 as Python 0.9.0.[37] Python 2.0 was released in 2000. Python 3.0, released in 2008, was a major revision not completely backward-compatible with earlier versions. Python 2.7.18, released in 2020, was the last release of Python 2.[38]
#
# Python consistently ranks as one of the most popular programming languages.[39][40][41][42] Python users are colloquially called pythonistas.
# ...

# %%
def extract_article_title(url):
        response = requests.get(url)
        response.raise_for_status() 

        soup = BeautifulSoup(response.content, 'html.parser')

        title = soup.title.string
        return title

url = "https://en.wikipedia.org/wiki/Python_(programming_language)"
title=extract_article_title(url)
print(title)
# Out:
# Python (programming language) - Wikipedia

# %%
def extract_article_with_headings(url):
    response = requests.get(url)
    response.raise_for_status() 
    soup = BeautifulSoup(response.content, 'html.parser')
    
    headings = soup.find_all(['h1', 'h2', 'h3', 'h4', 'h5', 'h6'])
    paragraphs = soup.find_all('p')
    article_data = []

    for heading, paragraph in zip(headings, paragraphs):
        
        heading_text = heading.get_text().strip()

        paragraph_text = paragraph.get_text().strip()

        article_data.append({'heading': heading_text, 'paragraph': paragraph_text})

    return article_data

url = "https://en.wikipedia.org/wiki/Python_(programming_language)"
article_data=extract_article_with_headings(url)
for data in article_data:
        print(data['heading'])
        print(data['paragraph'])
        print("---")
# Out:
# Contents
#
# ---
# Python (programming language)
#
# ---
# History
# Python is a high-level, general-purpose programming language. Its design philosophy emphasizes code readability with the use of significant indentation via the off-side rule.[34]
# ---
# Design philosophy and features
# Python is dynamically typed and garbage-collected. It supports multiple programming paradigms, including structured (particularly procedural), object-oriented and functional programming. It is often described as a "batteries included" language due to its comprehensive standard library.[35][36]
# ---
# Syntax and semantics
# Guido van Rossum began working on Python in the late 1980s as a successor to the ABC programming language and first released it in 1991 as Python 0.9.0.[37] Python 2.0 was released in 2000. Python 3.0, released in 2008, was a major revision not completely backward-compatible with earlier versions. Python 2.7.18, released in 2020, was the last release of Python 2.[38]
# ---
# ...

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlparse, urljoin

def is_wikipedia_link(url):
    return "wikipedia.org/wiki/" in url.lower()

def get_redirect_links(wikipedia_url):
    response = requests.get(wikipedia_url)
    response.raise_for_status()  # Check if the request was successful
    soup = BeautifulSoup(response.content, 'html.parser')
    
    redirect_links = []
    
    for link in soup.find_all('a', href=True):
        href = link['href']

        normalized_url = urljoin(wikipedia_url, href)
        
        if is_wikipedia_link(normalized_url) and "#redirect" in normalized_url.lower():
            redirect_links.append(normalized_url)
    
    return redirect_links

url = "https://en.wikipedia.org/wiki/Python_(programming_language)"
redirect_links = get_redirect_links(url)
for link in redirect_links:
    print(link)

# %%
def get_wikipedia_data(url):
    title = extract_article_title(url)
    print("Title:", title)

    article_data = extract_article_with_headings(url)
    for data in article_data:
        print(data['heading'])
        print(data['paragraph'])
        print("---")

    redirect_links = get_redirect_links(url)
    print("Redirect Links:")
    for link in redirect_links:
        print(link)

url = "https://en.wikipedia.org/wiki/Python_(programming_language)"
get_wikipedia_data(url)
# Out:
# Title: Python (programming language) - Wikipedia
# Contents
#
# ---
# Python (programming language)
#
# ---
# History
# Python is a high-level, general-purpose programming language. Its design philosophy emphasizes code readability with the use of significant indentation via the off-side rule.[34]
# ---
# Design philosophy and features
# Python is dynamically typed and garbage-collected. It supports multiple programming paradigms, including structured (particularly procedural), object-oriented and functional programming. It is often described as a "batteries included" language due to its comprehensive standard library.[35][36]
# ---
# Syntax and semantics
# ...
